# %% [markdown]
# <a href="https://colab.research.google.com/github/guillaumegodet/bibliometrie-notebooks/blob/main/demo/recherche_bookpi_HALcollection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================================================
# 📝 ÉTAPE 1 : INSTALLATION DES BIBLIOTHÈQUES
# =========================================================
# Cette ligne installe la bibliothèque 'requests' nécessaire.
# Elle est exécutée au début, une seule fois.
# %pip install requests

# =========================================================
# 📝 ÉTAPE 2 : CONFIGURATION (À MODIFIER PAR VOS SOINS)
# =========================================================
# ➡️ Entrez le nom de votre collection HAL

hal_collection = "nantes-universite"

# ➡️ Entrez la liste des revues que vous souhaitez interroger
#    Chaque titre de revue doit être entre guillemets et séparé par une virgule.
journal_list = [
    "Advances in Research on Teaching",
    "Archives of Current Research International",
    "Asian Basic and Applied Research Journal",
    "Asian Food Science Journal",
    "Asian Journal of Advanced Research and Reports",
    "Asian Journal of Advances in Agricultural Research",
    "Asian Journal of Advances in Research",
    "Asian Journal of Agricultural and Horticultural Research",
    "Asian Journal of Agricultural Extension, Economics and Sociology",
    "Asian Journal of Arts, Humanities and Social Studies",
    "Asian Journal of Biochemistry, Genetics and Molecular Biology",
    "Asian Journal of Biology",
    "Asian Journal of Cardiology Research",
    "Asian Journal of Case Reports in Medicine and Health",
    "Asian journal of case reports in surgery",
    "Asian Journal of Chemical Sciences",
    "Asian Journal of Current Research",
    "Asian Journal of Dental Sciences",
    "Asian Journal of Economics, Business and Accounting",
    "Asian Journal of Economics, Finance and Management",
    "Asian Journal of Education and Social Studies",
    "Asian Journal of Fisheries and Aquatic Research",
    "Asian Journal of Food Research and Nutrition",
    "Asian Journal of Language, Literature and Culture Studies",
    "Asian Journal of Medicine and Health",
    "Asian Journal of Microbiology, Biotechnology and Environmental Sciences",
    "Asian Journal of Orthopaedic Research",
    "Asian Journal of Pediatric Research",
    "Asian Journal of Plant and Soil Sciences",
    "Asian Journal of Research and Reports in Endocrinology",
    "Asian Journal of Research and Reviews in Physics",
    "Asian Journal of Research in Agriculture and Forestry",
    "Asian Journal of Research in Biochemistry",
    "Asian Journal of Research in Botany",
    "Asian Journal of Research in Computer Science",
    "Asian Journal of Research in Crop Science",
    "Asian Journal of Research in Dermatological Science",
    "Asian Journal of Research in Infectious Diseases",
    "Asian Journal of Research in Medicine and Medical Science",
    "Asian Journal of Research in Nephrology",
    "Asian Journal of Research in Nursing and Health",
    "Asian Journal of Research in Surgery",
    "Asian Journal of Research in Zoology",
    "Asian Journal of Sociological Research",
    "Asian Journal of Soil Science and Plant Nutrition",
    "Asian Research Journal of Agriculture",
    "Asian Research Journal of Arts & Social Sciences",
    "Asian Research Journal of Mathematics",
    "Cardiology and Angiology: An International Journal",
    "Chemical Science International Journal",
    "Current Journal of Applied Science and Technology",
    "European Journal of Nutrition and Food Safety",
    "International Journal of Advances in Nephrology Research",
    "International Journal of Biochemistry Research & Review",
    "International Journal of Environment and Climate Change",
    "International Journal of Hematology-Oncology and Stem Cell Research",
    "International Journal of Medical and Pharmaceutical Case Reports",
    "International Journal of Pathogen Research",
    "International Journal of Plant & Soil Science",
    "international journal of research and reports in dentistry",
    "International Journal of Research and Reports in Hematology",
    "International Neuropsychiatric Disease Journal",
    "International Research Journal of Gastroenterology and Hepatology",
    "International Research Journal of Oncology",
    "International Research Journal of Pure and Applied Chemistry",
    "Journal of Advances in Biology & Biotechnology",
    "Journal of Advances in Food Science & Technology",
    "Journal of Advances in Mathematics and Computer Science ",
    "Journal of Advances in Medicine and Medical Research",
    "Journal of Advances in Microbiology",
    "Journal of Agriculture and Ecology Research International",
    "Journal of Applied Chemical Science International",
    "Journal of Applied Life Sciences International",
    "Journal of Biochemistry International",
    "Journal of Biology and Nature",
    "Journal of Case Reports in Medical Science",
    "Journal of Complementary and Alternative Medical Research",
    "Journal of Economics and Trade",
    "Journal of Economics, Management and Trade",
    "Journal of Education, Society and Behavioural Science",
    "Journal of Engineering Research and Reports",
    "Journal of Experimental Agriculture International",
    "Journal of Geography, Environment and Earth Science International",
    "Journal of Global Ecology and Environment",
    "Journal of Materials Science Research and Reviews",
    "Journal of Pharmaceutical Research International",
    "Journal of Scientific Research and Reports",
    "Ophthalmology Research: An International Journal",
    "Physical Science International Journal",
    "Plant Cell Biotechnology and Molecular Biology",
    "South Asian Journal of Research in Microbiology",
    "South Asian Journal of Social Studies and Economics",
    "UTTAR PRADESH JOURNAL OF ZOOLOGY"
]

# =========================================================
# ⚙️ ÉTAPE 3 : EXÉCUTION DU SCRIPT (NE PAS MODIFIER)
# =========================================================
# Le code des fonctions est placé ici, pour qu'il soit défini avant d'être appelé.
import requests
import time

def get_hal_publications(collection, journals):
    """
    Interroge l'API HAL pour trouver les publications d'une collection
    spécifique pour une liste de revues, en utilisant le point d'entrée
    de l'instance de collection pour une meilleure fiabilité.
    """
    base_url = f"https://api.archives-ouvertes.fr/search/{collection}"
    results = {}

    print(f"Lancement de la recherche de publications dans la collection '{collection}'...")

    for journal_title in journals:
        print(f"\nRecherche pour la revue : '{journal_title}'...")

        query = f'journalTitle_s:("{journal_title}")'
        params = {
            'q': query,
            'rows': 100,
            'fl': 'halId_s,title_s,contributorFullName_s,submittedDate_s'
        }

        try:
            response = requests.get(base_url, params=params)
            response.raise_for_status()
            data = response.json()
            docs = data.get('response', {}).get('docs', [])

            if docs:
                results[journal_title] = docs
                print(f"  -> ✅ {len(docs)} publication(s) trouvée(s).")
            else:
                print(f"  -> ❌ Aucune publication trouvée pour cette revue dans la collection.")
        except requests.exceptions.RequestException as e:
            print(f"Erreur lors de la requête pour '{journal_title}': {e}")

        time.sleep(0.5)

    return results

def display_results(publications):
    """
    Affiche les résultats de la recherche de manière lisible.
    """
    if not publications:
        print("Aucune publication trouvée pour les critères spécifiés.")
        return

    for journal, docs in publications.items():
        print("\n" + "="*80)
        print(f"  ▶️ PUBLICATIONS TROUVÉES DANS LA REVUE '{journal}'")
        print("="*80)

        for i, doc in enumerate(docs):
            title = doc.get('title_s', ['(Titre non disponible)'])[0]
            hal_id = doc.get('halId_s', None)
            uri = f"https://hal.science/{hal_id}" if hal_id else "(Lien non disponible)"

            contributors = doc.get('contributorFullName_s', ['Auteurs non disponibles'])
            if isinstance(contributors, str):
                contributors = [contributors]
            authors = ', '.join(contributors)

            print(f"  {i+1}. Titre : {title}")
            print(f"     Contributeur : {authors}")
            print(f"     Lien HAL : {uri}")
            print("-" * 70)

# Exécution du script principal
extracted_publications = get_hal_publications(hal_collection, journal_list)
display_results(extracted_publications)

print("\nFin de l'exécution.")
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.8.3)
# Lancement de la recherche de publications dans la collection 'nantes-universite'...
#
# Recherche pour la revue : 'Advances in Research on Teaching'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Archives of Current Research International'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Basic and Applied Research Journal'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Food Science Journal'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Advanced Research and Reports'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Advances in Agricultural Research'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Advances in Research'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Agricultural and Horticultural Research'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Agricultural Extension, Economics and Sociology'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Arts, Humanities and Social Studies'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Biochemistry, Genetics and Molecular Biology'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Biology'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Cardiology Research'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Case Reports in Medicine and Health'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian journal of case reports in surgery'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Chemical Sciences'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Current Research'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Dental Sciences'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Economics, Business and Accounting'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Economics, Finance and Management'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Education and Social Studies'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Fisheries and Aquatic Research'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Food Research and Nutrition'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Language, Literature and Culture Studies'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Medicine and Health'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Microbiology, Biotechnology and Environmental Sciences'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Orthopaedic Research'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Pediatric Research'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Plant and Soil Sciences'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Research and Reports in Endocrinology'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Research and Reviews in Physics'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Research in Agriculture and Forestry'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Research in Biochemistry'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Research in Botany'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Research in Computer Science'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Research in Crop Science'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Research in Dermatological Science'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Research in Infectious Diseases'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Research in Medicine and Medical Science'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Research in Nephrology'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Research in Nursing and Health'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Research in Surgery'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Research in Zoology'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Sociological Research'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Journal of Soil Science and Plant Nutrition'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Research Journal of Agriculture'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Research Journal of Arts & Social Sciences'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Asian Research Journal of Mathematics'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Cardiology and Angiology: An International Journal'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Chemical Science International Journal'...
#   -> ✅ 1 publication(s) trouvée(s).
#
# Recherche pour la revue : 'Current Journal of Applied Science and Technology'...
#   -> ✅ 2 publication(s) trouvée(s).
#
# Recherche pour la revue : 'European Journal of Nutrition and Food Safety'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'International Journal of Advances in Nephrology Research'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'International Journal of Biochemistry Research & Review'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'International Journal of Environment and Climate Change'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'International Journal of Hematology-Oncology and Stem Cell Research'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'International Journal of Medical and Pharmaceutical Case Reports'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'International Journal of Pathogen Research'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'International Journal of Plant & Soil Science'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'international journal of research and reports in dentistry'...
#   -> ✅ 1 publication(s) trouvée(s).
#
# Recherche pour la revue : 'International Journal of Research and Reports in Hematology'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'International Neuropsychiatric Disease Journal'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'International Research Journal of Gastroenterology and Hepatology'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'International Research Journal of Oncology'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'International Research Journal of Pure and Applied Chemistry'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Advances in Biology & Biotechnology'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Advances in Food Science & Technology'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Advances in Mathematics and Computer Science '...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Advances in Medicine and Medical Research'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Advances in Microbiology'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Agriculture and Ecology Research International'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Applied Chemical Science International'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Applied Life Sciences International'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Biochemistry International'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Biology and Nature'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Case Reports in Medical Science'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Complementary and Alternative Medical Research'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Economics and Trade'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Economics, Management and Trade'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Education, Society and Behavioural Science'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Engineering Research and Reports'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Experimental Agriculture International'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Geography, Environment and Earth Science International'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Global Ecology and Environment'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Materials Science Research and Reviews'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Pharmaceutical Research International'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Journal of Scientific Research and Reports'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Ophthalmology Research: An International Journal'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Physical Science International Journal'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'Plant Cell Biotechnology and Molecular Biology'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'South Asian Journal of Research in Microbiology'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'South Asian Journal of Social Studies and Economics'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# Recherche pour la revue : 'UTTAR PRADESH JOURNAL OF ZOOLOGY'...
#   -> ❌ Aucune publication trouvée pour cette revue dans la collection.
#
# ================================================================================
#   ▶️ PUBLICATIONS TROUVÉES DANS LA REVUE 'Chemical Science International Journal'
# ================================================================================
#   1. Titre : Synthesis of New Dihydropyrimidine-2-Thione Derivatives and Their Antibacterial Screening
#      Contributeur : Silent Echo
#      Lien HAL : https://hal.science/hal-05086170
# ----------------------------------------------------------------------
#
# ================================================================================
#   ▶️ PUBLICATIONS TROUVÉES DANS LA REVUE 'Current Journal of Applied Science and Technology'
# ================================================================================
#   1. Titre : Numerical Investigation of the Effects of Insulated Envelopes on Hygrothermal Comfort within Habitats of Southern Benin: Test of a Local Material
#      Contributeur : Nathalie Robert
#      Lien HAL : https://hal.science/hal-03164085
# ----------------------------------------------------------------------
#   2. Titre : Dimensioning of a Water Pumping System by the Systematic Scanning Method
#      Contributeur : Nathalie Robert
#      Lien HAL : https://hal.science/hal-03164028
# ----------------------------------------------------------------------
#
# ================================================================================
#   ▶️ PUBLICATIONS TROUVÉES DANS LA REVUE 'international journal of research and reports in dentistry'
# ================================================================================
#   1. Titre : Comparing the Incidence and Prevalence of Oral Microbial Pathogens Selenomonas noxia and Streptococcus mitis within the UNLV-SDM Clinical Patient Population
#      Contributeur : Scope Synced
#      Lien HAL : https://hal.science/hal-05227843
# ----------------------------------------------------------------------
#
# Fin de l'exécution.
